# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
Data = open('Data.txt','r').read()
dataLines = Data.split('\n')
Temp = []
M = []
Energy = []
Cv = []
X = []

for eachLine in dataLines:
    if len(eachLine) > 1:
        line = eachLine.split(' ')
        Temp.append(float(line[0]))
        Energy.append(float(line[1]))
        M.append(float(line[2]))
        Cv.append(float(line[3]))
        X.append(float(line[4]))

# %%
plt.scatter(Temp, Energy, marker = '.')
#plt.xlim([0, 1000])
plt.show()

# %%
plt.scatter(Temp, M, marker = '.')
plt.show()

# %%
plt.scatter(Temp, Cv, marker = '.')
plt.show()

# %%
plt.scatter(Temp, X, marker = '.')
plt.show()
